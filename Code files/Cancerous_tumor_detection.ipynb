# %% [markdown]
# # Import of Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # File read

# %%
# Set display options
pd.set_option("display.max_rows", 15)
pd.options.mode.chained_assignment = None

# File paths
dataset_folder = 'Datasets'
filename1 = f'{dataset_folder}/data11tumors2.csv'
filename2 = f'{dataset_folder}/plasmatumor_data.csv'
filename3 = f'{dataset_folder}/braintumor_data.csv'

# Reading the CSV files
training_data1 = pd.read_csv(data11tumors2)
training_data2 = pd.read_csv(plasmatumor_data)
training_data3 = pd.read_csv(braintumor_data)

# Displaying the data from the three CSV files
print("Data from the first CSV file (data11tumors2.csv):")
print(training_data1)
print("\nData from the second CSV file (plasmatumor_data.csv):")
print(training_data2)
print("\nData from the third CSV file (braintumor_data.csv):")
print(training_data3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       9 filename3 = f'{dataset_folder}/braintumor_data.csv'
#      11 # Reading the CSV files
# ---> 12 training_data1 = pd.read_csv(data11tumors2)
#      13 training_data2 = pd.read_csv(plasmatumor_data)
#      14 training_data3 = pd.read_csv(braintumor_data)
#
# NameError: name 'data11tumors2' is not defined

# %% [markdown]
# # Concatenating data

# %%
# Concatenate the dataframes
training_data = pd.concat([training_data1, training_data2, training_data3], ignore_index=True)

# Display the combined dataframe
print(training_data)

# %% [markdown]
# # Basic statistics

# %%
training_data.describe()
# Out:
#             Class          D1           D2          D3           D4  \
# count  522.000000  522.000000   522.000000  522.000000   522.000000
# mean     1.809412   73.127432   179.649728   24.341684    28.235036
# std      2.642919  123.054772   297.194733   42.119598    80.939569
# min      0.000000 -122.000000     0.000775  -24.000000   -80.000000
# 25%      0.295427    0.344888     0.363504    0.416145     0.324983
# 50%      0.686900    0.720827     0.733001    0.772491     0.718325
# 75%      2.000000  147.500000   358.000000   44.000000    24.000000
# max     10.000000  616.000000  1419.000000  247.000000  1307.000000
#
#                D5          D6           D7            D8           D9  ...  \
# count  522.000000  522.000000   522.000000    522.000000   522.000000  ...
# mean   -22.050032   -5.196014   215.297535     25.863864   491.303573  ...
# std     87.479795   37.091434   699.140662    498.799980   789.321564  ...
# min   -900.000000 -206.000000  -551.000000   -205.000000     0.004211  ...
# 25%      0.025265    0.058039     0.160023     -2.249651     0.389148  ...
# 50%      0.399310    0.446621     0.533836      0.364617     0.753777  ...
# 75%      0.798911    0.807772     0.944002      0.732028  1047.750000  ...
# max    264.000000  138.000000  5218.000000  10019.000000  4120.000000  ...
#
#            D12524      D12525      D12526      D12527      D12528      D12529  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000  522.000000
# mean    -0.110102   31.368169   46.350101    1.285377   33.002809   21.291506
# std     55.421493   51.107316   75.771435   25.706627   71.829915   55.097875
# min   -235.000000    0.000357  -26.000000 -146.000000 -349.000000 -184.000000
# 25%      0.084232    0.374951    0.379301    0.213074    0.332152    0.325635
# 50%      0.496802    0.740385    0.772488    0.550531    0.727432    0.688144
# 75%      0.851733   59.000000   91.750000    0.901832   44.250000   15.250000
# max    452.000000  270.000000  414.000000  100.000000  480.000000  485.000000
#
#            D12530      D12531       D12532       D12533
# count  522.000000  522.000000   522.000000   522.000000
# mean    34.454904    4.634309    69.316150   -73.305931
# std     87.902135   16.865476   251.564946   163.139529
# min    -75.000000  -56.000000     0.000748  -992.000000
# 25%      0.299694    0.226721     0.376537  -142.000000
# 50%      0.629199    0.548050     0.754922     0.235631
# 75%     19.500000    0.961892    96.000000     0.621900
# max    896.000000  109.000000  4888.000000  1351.000000
#
# [8 rows x 12534 columns]

# %% [markdown]
# # class distribution

# %%
# class distribution
print(training_data.groupby('Class').size())
# Out:
# Class
# 0.000000     27
# 0.003683      1
# 0.005431      1
# 0.009173      1
# 0.017514      1
#              ..
# 6.000000      7
# 7.000000     26
# 8.000000      6
# 9.000000     14
# 10.000000    14
# Length: 359, dtype: int64

# %% [markdown]
# # Separation of labels and features

# %%
label_vectors = training_data['Class'].values
feature_vectors = training_data.drop(['Class'], axis=1).values
label_vectors
# Out:
# array([7.00000000e+00, 7.00000000e+00, 7.00000000e+00, 7.00000000e+00,
#        7.00000000e+00, 7.00000000e+00, 7.00000000e+00, 7.00000000e+00,
#        7.00000000e+00, 7.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 2.00000000e+00, 2.00000000e+00,
#        2.00000000e+00, 2.00000000e+00, 2.00000000e+00, 2.00000000e+00,
#        2.00000000e+00, 2.00000000e+00, 2.00000000e+00, 2.00000000e+00,
#        2.00000000e+00, 2.00000000e+00, 3.00000000e+00, 3.00000000e+00,
#        3.00000000e+00, 3.00000000e+00, 3.00000000e+00, 3.00000000e+00,
#        3.00000000e+00, 3.00000000e+00, 3.00000000e+00, 3.00000000e+00,
#        3.00000000e+00, 4.00000000e+00, 4.00000000e+00, 4.00000000e+00,
#        4.00000000e+00, 4.00000000e+00, 4.00000000e+00, 4.00000000e+00,
#        4.00000000e+00, 4.00000000e+00, 4.00000000e+00, 4.00000000e+00,
#        5.00000000e+00, 5.00000000e+00, 5.00000000e+00, 5.00000000e+00,
#        5.00000000e+00, 5.00000000e+00, 5.00000000e+00, 5.00000000e+00,
#        5.00000000e+00, 5.00000000e+00, 6.00000000e+00, 6.00000000e+00,
#        6.00000000e+00, 6.00000000e+00, 6.00000000e+00, 6.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 8.00000000e+00, 8.00000000e+00, 8.00000000e+00,
#        8.00000000e+00, 8.00000000e+00, 8.00000000e+00, 9.00000000e+00,
#        9.00000000e+00, 9.00000000e+00, 9.00000000e+00, 9.00000000e+00,
#        9.00000000e+00, 9.00000000e+00, 9.00000000e+00, 9.00000000e+00,
#        1.00000000e+01, 1.00000000e+01, 1.00000000e+01, 1.00000000e+01,
#        1.00000000e+01, 1.00000000e+01, 1.00000000e+01, 1.00000000e+01,
#        2.00000000e+00, 1.00000000e+01, 4.00000000e+00, 3.00000000e+00,
#        0.00000000e+00, 6.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.00000000e+00, 2.00000000e+00, 9.00000000e+00, 1.00000000e+01,
#        7.00000000e+00, 7.00000000e+00, 2.00000000e+00, 2.00000000e+00,
#        5.00000000e+00, 2.00000000e+00, 0.00000000e+00, 9.00000000e+00,
#        3.00000000e+00, 3.00000000e+00, 3.00000000e+00, 3.00000000e+00,
#        3.00000000e+00, 3.00000000e+00, 3.00000000e+00, 3.00000000e+00,
#        3.00000000e+00, 3.00000000e+00, 9.00000000e+00, 1.00000000e+01,
#        9.00000000e+00, 1.00000000e+01, 1.00000000e+01, 9.00000000e+00,
#        1.00000000e+01, 2.00000000e+00, 2.00000000e+00, 2.00000000e+00,
#        2.00000000e+00, 2.00000000e+00, 2.00000000e+00, 2.00000000e+00,
#        2.00000000e+00, 2.00000000e+00, 7.00000000e+00, 7.00000000e+00,
#        7.00000000e+00, 7.00000000e+00, 7.00000000e+00, 7.00000000e+00,
#        7.00000000e+00, 7.00000000e+00, 7.00000000e+00, 7.00000000e+00,
#        7.00000000e+00, 7.00000000e+00, 7.00000000e+00, 7.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1
#        4.63134406e-01, 9.24826532e-01, 9.70025605e-01, 9.14484457e-01,
#        1.98713786e-02, 1.93410865e-01, 3.76287433e-01, 1.96045254e-01,
#        4.14710323e-01, 7.79160406e-01, 1.98626094e-02, 1.85620490e-01,
#        7.17491116e-01, 8.54081218e-01, 6.76319261e-01, 4.86364124e-01,
#        9.41375178e-01, 8.13025449e-01, 3.10643524e-01, 3.89597691e-01,
#        5.49738804e-01, 6.76483477e-01, 7.38158509e-01, 2.02786446e-01,
#        8.68723183e-01, 4.16107372e-01, 2.72787443e-01, 3.10894762e-01,
#        8.88320907e-01, 1.80076558e-01, 5.14013446e-01, 9.57319786e-01,
#        2.86050963e-01, 2.30510710e-01, 4.21012975e-01, 3.99821750e-01,
#        1.14475527e-01, 7.17209626e-01, 9.23712538e-01, 9.70429999e-02,
#        1.42947999e-01, 6.11110661e-01, 1.13764318e-01, 1.86969015e-01,
#        3.12197364e-01, 7.96308345e-01, 3.92461346e-01, 1.41363871e-01,
#        1.02708676e-01, 9.63823973e-01, 6.27050694e-01, 3.59247351e-01,
#        7.96148832e-01, 9.26483116e-01, 7.92250480e-01, 4.65914523e-01,
#        6.33024779e-01, 9.83412386e-01, 7.04193043e-01, 9.01081914e-01,
#        6.33421729e-01, 6.83948751e-01, 2.27218548e-01, 9.56266568e-01,
#        3.47102077e-01, 6.00556336e-01, 4.98239697e-01, 3.56808902e-01,
#        4.30807316e-01, 6.09883503e-01, 2.45888340e-01, 8.17450464e-01,
#        5.46932633e-02, 2.85304492e-01, 1.63756116e-01, 3.08890424e-01,
#        5.01125559e-01, 5.12582343e-01])

# %% [markdown]
# # Information scaling

# %%
scaler = preprocessing.StandardScaler().fit(feature_vectors)
feature_vectors_scaler = scaler.transform(feature_vectors)

# %% [markdown]
# # Information Split - without scaling

# %%
validation_size = 0.2
seed = 7
X_train, X_validation, Y_train, Y_validation = train_test_split(feature_vectors, label_vectors, test_size=validation_size, random_state=seed)
X_train.shape
# Out:
# (417, 12533)

# %% [markdown]
# # Information Split with scaling

# %%
validation_size = 0.2
seed = 7
X_trainScaler, X_validationScaler, Y_trainScaler, Y_validationScaler = train_test_split(feature_vectors_scaler, label_vectors, 
                                                                                        test_size=validation_size, 
                                                                                        random_state=seed)

# %% [markdown]
# # PCA - without scaling

# %%
pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(X_train)
X_trainPCA = pca.transform(X_train)
X_validationPCA=pca.transform(X_validation)
print('X_PCA:',X_trainPCA.shape)
# Out:
# X_PCA: (417, 46)

# %% [markdown]
# # PCA - with scaling

# %%
pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(feature_vectors)
feature_vectorsPCA = pca.transform(feature_vectors)

pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(feature_vectors_scaler)
feature_vectorsPCA_Scaler = pca.transform(feature_vectors_scaler)

pca = decomposition.PCA(n_components=0.96,svd_solver='full',tol=1e-4)
pca.fit(X_trainScaler)
X_trainPCAScaler = pca.transform(X_trainScaler)
X_validationPCAScaler=pca.transform(X_validationScaler)
print('X_PCA:',X_trainPCAScaler.shape)
# Out:
# X_PCA: (417, 103)
